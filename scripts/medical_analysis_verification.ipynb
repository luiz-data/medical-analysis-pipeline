# %%
import pandas as pd 

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
claims_transactions = pd.read_csv('../../medical_analysis/data/claims_transactions.csv')
claims = pd.read_csv('../../medical_analysis/data/claims.csv')
encounters = pd.read_csv('../../medical_analysis/data/encounters.csv')
patients = pd.read_csv('../../medical_analysis/data/patients.csv')
payers = pd.read_csv('../../medical_analysis/data/payers.csv')

# %%
print("claims_transactions shape: ",  claims_transactions.shape)
print("claims shape: ",  claims.shape)
print("encounters shape: ",  encounters.shape)
print("patients shape: ",  patients.shape)
print("payers shape: ",  payers.shape)
# Out:
# claims_transactions shape:  (711238, 33)
# claims shape:  (117889, 31)
# encounters shape:  (61459, 15)
# patients shape:  (1163, 25)
# payers shape:  (10, 21)

# %%
print("Dados do claims_transactions")
display(claims_transactions.head(2), claims_transactions.tail(2))

print("\nDados do claims")
display(claims.head(2), claims.tail(2))

print("\nDados do encounters")
display(encounters.head(2), encounters.tail(2))

print("\nDados do patients")
display(patients.head(2), patients.tail(2))

print("\nDados do payers")
display(payers.head(2), payers.tail(2))
# Out:
# Dados do claims_transactions
#                                      ID                               CLAIMID  \
# 0  5c58de0b-3ba9-401d-2ce7-a4785ff35c15  e413105d-6f23-34ef-724a-b42adab9df22
# 1  1a647606-c7fa-a050-8802-6c06418ee151  e413105d-6f23-34ef-724a-b42adab9df22
#
#    CHARGEID                             PATIENTID     TYPE  AMOUNT  METHOD  \
# 0         0  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85   CHARGE  129.16     NaN
# 1         1  b9c610cd-28a6-4636-ccb6-c7a0d2a4cb85  PAYMENT     NaN  ECHECK
#
#                FROMDATE                TODATE  \
# 0  2019-02-17T05:07:38Z  2019-02-17T05:22:38Z
# 1  2019-02-17T05:07:38Z  2019-02-17T05:22:38Z
#
#                          PLACEOFSERVICE  PROCEDURECODE  MODIFIER1  MODIFIER2  \
# 0  f7ae497d-8dc6-3721-9402-43b621a4e7d2      410620009        NaN        NaN
# 1  f7ae497d-8dc6-3721-9402-43b621a4e7d2      410620009        NaN        NaN
#
#    DIAGNOSISREF1  DIAGNOSISREF2  DIAGNOSISREF3  DIAGNOSISREF4  UNITS  \
# ...
